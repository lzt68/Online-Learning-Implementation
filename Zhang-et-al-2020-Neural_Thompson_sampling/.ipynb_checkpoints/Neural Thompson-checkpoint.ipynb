# %% [markdown]
# # Neural Thompson Sampling
#
# <img src="./Figure/algorithm1.png" style="zoom:80%" />
#
# <img src="./Figure/Loss_Function.png" style="zoom:80%" />
#
# This paper prove the bound of expected regret bound, but it directly apply its algorithm on the classification problem, without a testing on online learning theorem.
#
# It might be quite hard to compare its performance on online learning theory.
#
# we set the real reward := 2 * np.exp(A^T context) / (1 + np.exp(A^T context)) - 1 + np.random.normal(loc=0, scale=1)

# %%
# %reset -f
import numpy as np
import random
from copy import deepcopy
from GameSetting import *
from NeuralNetworkRelatedFunction import *

# %%
class NeuralAgent:
    def __init__(self, K, T, d, L = 2, m = 20, v = 0.1, lambda_ = 0.01, eta = 0.001, frequency = 50, batchsize = None):
        # K is Total number of actions,
        # T is Total number of periods
        # d is the dimension of context
        self.K = K
        self.T = T
        self.d = d
        
        self.L = L
        self.m = m
        self.v = v
        self.lambda_ = lambda_
        self.eta = eta
        self.frequency = frequency # we train the network after frequency, e.g. per 50 round
        self.batchsize = batchsize
        self.t = 0 # marks the index of period
        self.history_reward = np.zeros(T)
        self.history_action = np.zeros(T)
        self.predicted_reward = np.zeros(T)
        self.history_context = np.zeros((d, T))
        
        # initialize the value of parameter
        np.random.seed(12345)
        self.theta_0 = {}
        W = np.random.normal(loc = 0, scale = 4 / m, size=(int(m/2), int(m/2)))
        w = np.random.normal(loc = 0, scale = 2 / m, size=(1, int(m/2)))
        for key in range(1, L + 1):
            if key == 1:
                # this paper doesn't present the initialization of w1
                # in its setting, d = m, then he let theta_0["w1"]=[W,0;0,W]
                # but in fact d might not equal to m
                tempW = np.random.normal(loc = 0, scale = 4 / m, size=(int(m/2), int(d/2)))
                self.theta_0["w1"] = np.zeros((m, d))
                self.theta_0["w1"][0:int(m/2), 0:int(d/2)] = tempW
                self.theta_0["w1"][int(m/2):, int(d/2):] = tempW
            elif 2 <= key and key <= L - 1:
                self.theta_0["w" + str(key)] = np.zeros((m, m))
                self.theta_0["w" + str(key)][0:int(m/2), 0:int(m/2)] = W
                self.theta_0["w" + str(key)][int(m/2):, int(m/2):] = W
            else:
                self.theta_0["w" + str(key)] = np.concatenate([w, -w], axis = 1)
                
        self.p = m + m * d + m * m * (L - 2)
        self.params = deepcopy(self.theta_0)
        self.U = lambda_ * np.eye(self.p)
        self.params_history = {}
        self.grad_history = {}
    
    def Action(self, context_list):
        # context_list is a d*K matrix, each column represent a context
        # the return value is the action we choose, represent the index of action, is a scalar
        sample_estimated_reward = np.zeros(K) # the upper bound of K actions
        predict_reward = np.zeros(K)
        U_inverse = np.linalg.inv(self.U)
        for a in range(1, K + 1):
            predict_reward[a - 1] = NeuralNetwork(context_list[:, a - 1], self.params, self.L, self.m)['x' + str(self.L)][0]
            grad_parameter = GradientNeuralNetwork(context_list[:, a - 1], self.params, self.L, self.m)
            grad_parameter = FlattenDict(grad_parameter, self.L)
            sigma_square = self.lambda_ * grad_parameter.dot(U_inverse).dot(grad_parameter) / self.m
            sigma = np.sqrt(sigma_square)
            
            sample_estimated_reward[a - 1] = np.random.normal(loc = predict_reward[a - 1], scale = self.v * sigma)
            
        ind = np.argmax(sample_estimated_reward, axis=None)
        self.predicted_reward[self.t] = sample_estimated_reward[ind]
        self.history_action[self.t] = ind
        self.history_context[:, self.t] = context_list[:, ind]
        return ind
    
    def Update(self, reward):
        # reward is the realized reward after we adopt policy, a scalar
#         print("round {:d}".format(self.t))
        self.history_reward[self.t] = reward
        ind = self.history_action[self.t]
        context = self.history_context[:, self.t]
        
        # compute Z_t_minus1
        grad_parameter = GradientNeuralNetwork(context, self.params, self.L, self.m)
        grad_parameter = FlattenDict(grad_parameter, self.L)
        grad_parameter = np.expand_dims(grad_parameter, axis = 1)
        self.U = self.U + grad_parameter.dot(grad_parameter.transpose()) / self.m

        # train neural network
        if self.t % self.frequency == 0 and self.t > 0:
            J = self.t
        else:
            J = 0
            
        if self.batchsize == None:
            trainindex = range(0, self.t + 1)
        else:
            if self.batchsize > self.t + 1:
                trainindex = range(0, self.t + 1)
            else:
                trainindex = random.sample(range(0, self.t + 1), self.batchsize)
                
        grad_loss = {}
        for j in range(J):
            
            grad_loss = GradientLossFunction(self.history_context[:, trainindex],# we had not update self.t yet, so here we must +1
                                             self.params, 
                                             self.L, 
                                             self.m, 
                                             self.history_reward[trainindex], 
                                             self.theta_0, 
                                             self.lambda_)
#             if j < 10:
#                 eta = 1e-4
#             else:
#                 eta = self.eta
            eta = self.eta
            for key in self.params.keys():
                self.params[key] = self.params[key] - eta * grad_loss[key]
            loss = LossFunction(self.history_context[:, trainindex],
                            self.params, 
                            self.L, 
                            self.m,
                            self.history_reward[trainindex],
                            self.theta_0,
                            self.lambda_)
#             print("j {:d}, loss {:4f}".format(j, loss))
        
        print("round {:d}, predicted reward {:4f}, actual reward {:4f}".format(self.t,
                                                                               self.predicted_reward[self.t], 
                                                                               reward))

        self.params_history[self.t] = deepcopy(self.params)
        self.grad_history[self.t] = deepcopy(grad_loss)
        
        self.t = self.t + 1

# %%
class BestAgent:
    def __init__(self, K, T, d):
        # K is Total number of actions,
        # T is Total number of periods
        # d is the dimension of context
        self.K = K
        self.T = T
        self.d = d
        self.t = 0 # marks the index of period
        self.history_reward = np.zeros(T)
        self.history_action = np.zeros(T)
        self.history_context = np.zeros((d, T))
    
    def Action(self, context_list):
        # context_list is a d*K matrix, each column represent a context
        # the return value is the action we choose, represent the index of action, is a scalar
        
        expected_reward = np.zeros(K)
        for kk in range(0, K):
            context = context_list[:, kk]
            innerproduct = A.dot(context)
            expected_reward[kk] = 2 * np.exp(innerproduct) / (1 + np.exp(innerproduct))
        ind = np.argmax(expected_reward, axis=None)
        self.history_context[:, self.t] = context_list[:, ind]
        self.history_action[self.t] = ind
        return ind
    
    def Update(self, reward):
        # reward is the realized reward after we adopt policy, a scalar
        self.history_reward[self.t] = reward
        self.t = self.t + 1

# %%
class UniformAgent:
    def __init__(self, K, T, d):
        # K is Total number of actions,
        # T is Total number of periods
        # d is the dimension of context
        self.K = K
        self.T = T
        self.d = d
        self.t = 0 # marks the index of period
        self.history_reward = np.zeros(T)
        self.history_action = np.zeros(T)
        self.history_context = np.zeros((d, T))
    
    def Action(self, context_list):
        # context_list is a d*K matrix, each column represent a context
        # the return value is the action we choose, represent the index of action, is a scalar
        
        ind = np.random.randint(0, high = K) # we just uniformly choose an action
        self.history_context[:, self.t] = context_list[:, ind]
        return ind
    
    def Update(self, reward):
        # reward is the realized reward after we adopt policy, a scalar
        self.history_reward[self.t] = reward
        self.t = self.t + 1
        
    def GetHistoryReward(self):
        return self.history_reward
    
    def GetHistoryAction(self):
        return self.history_action
    
    def GetHistoryContext(self):
        return self.history_context

# %%
# Set the parameter of the game
np.random.seed(12345)
K = 4# Total number of actions, 
T = 5000 # Total number of periods
d = 10 # the dimension of context
A = np.random.normal(loc=0, scale=1, size = d)

# %%
# Neural Thompson sampling
np.random.seed(12345)

# Set the parameter of the network
# the setting is based on the description of section 7.1 of the papaer
L = 2
m = 10 
v = 0.1 #{0.01, 0.1, 1}
lambda_ = 1 #{0.1, 1, 10}
eta = 1e-4 #{0.001, 0.01, 0.1}
frequency = 50
batchsize = 500
# we set J equal to round index t

neuralagent = NeuralAgent(K, T, d, L, m, v, lambda_, eta, frequency, batchsize)
for tt in range(1, T + 1):
    # observe \{x_{t,a}\}_{a=1}^{k=1}
    context_list = SampleContext(d, K)
    
    # compute the upper bound of reward
    ind = neuralagent.Action(context_list)
    
    # play ind and observe reward
    reward = GetRealReward(context_list[:, ind], A)
    neuralagent.Update(reward)
# Out:
# round 0, predicted reward 0.148176, actual reward 0.244740
# round 1, predicted reward 0.022844, actual reward 0.563030
# round 2, predicted reward 0.292856, actual reward 0.195210
# round 3, predicted reward 0.034788, actual reward 0.261966
# round 4, predicted reward 0.241494, actual reward 0.547694
# round 5, predicted reward 0.294280, actual reward 0.403253
# round 6, predicted reward 0.157398, actual reward 0.201512
# round 7, predicted reward 0.306764, actual reward 0.100068
# round 8, predicted reward 0.069192, actual reward 0.414156
# round 9, predicted reward 0.196820, actual reward 0.166924
# round 10, predicted reward 0.311780, actual reward 0.073694
# round 11, predicted reward 0.388526, actual reward 0.606803
# round 12, predicted reward 0.176393, actual reward 0.417585
# round 13, predicted reward 0.080025, actual reward -0.422391
# round 14, predicted reward 0.226923, actual reward -0.036049
# round 15, predicted reward 0.149136, actual reward 0.153878
# round 16, predicted reward 0.296422, actual reward 0.489971
# round 17, predicted reward 0.004391, actual reward 0.186953
# round 18, predicted reward 0.098594, actual reward -0.006198
# round 19, predicted reward 0.219182, actual reward 0.543981
# round 20, predicted reward 0.208436, actual reward 0.450029
# round 21, predicted reward 0.132313, actual reward 0.047310
# round 22, predicted reward 0.263492, actual reward -0.452989
# round 23, predicted reward 0.339155, actual reward 0.544113
# round 24, predicted reward 0.252470, actual reward 0.375494
# round 25, predicted reward 0.207072, actual reward 0.026713
# round 26, predicted reward 0.187078, actual reward -0.047080
# round 27, predicted reward 0.181123, actual reward 0.020368
# round 28, predicted reward 0.144525, actual reward -0.217150
# round 29, predicted reward 0.254214, actual reward -0.400774
# round 30, predicted reward 0.246752, actual reward -0.301132
# round 31, predicted reward 0.107666, actual reward 0.677547
# round 32, predicted reward 0.071663, actual reward 0.739376
# round 33, predicted reward 0.206566, actual reward 0.728265
# round 34, predicted reward 0.190193, actual reward 0.369037
# round 35, predicted reward 0.495945, actual reward 0.422578
# round 36, predicted reward 0.002813, actual reward -0.521090
# round 37, predicted reward 0.118181, actual reward 0.075766
# round 38, predicted reward 0.313852, actual reward 0.727995
# round 39, predicted reward 0.279445, actual reward 0.450118
# round 40, predicted reward 0.300387, actual reward 0.271673
# round 41, predicted reward -0.009259, actual reward 0.799664
# round 42, predicted reward 0.083812, actual reward 0.323165
# round 43, predicted reward 0.049589, actual reward -0.112547
# round 44, predicted reward 0.273921, actual reward -0.005573
# round 45, predicted reward 0.118012, actual reward 0.398975
# round 46, predicted reward 0.223812, actual reward -0.366733
# round 47, predicted reward 0.225749, actual reward 0.001306
# round 48, predicted reward 0.191758, actual reward -0.201324
# round 49, predicted reward 0.358363, actual reward 0.716602
# round 50, predicted reward 0.211739, actual reward 0.185512
# round 51, predicted reward 0.034046, actual reward 0.322155
# round 52, predicted reward 0.235689, actual reward 0.039764
# round 53, predicted reward 0.135711, actual reward 0.628644
# round 54, predicted reward 0.152737, actual reward -0.109011
# round 55, predicted reward 0.255736, actual reward 0.087355
# round 56, predicted reward 0.218170, actual reward 0.450259
# round 57, predicted reward 0.277691, actual reward 0.485547
# round 58, predicted reward 0.196658, actual reward 0.040585
# round 59, predicted reward 0.120033, actual reward -0.188002
# round 60, predicted reward 0.336737, actual reward -0.232533
# round 61, predicted reward 0.114762, actual reward 0.457533
# round 62, predicted reward 0.111972, actual reward 0.072403
# round 63, predicted reward 0.212671, actual reward 0.366783
# round 64, predicted reward 0.048661, actual reward -0.137880
# round 65, predicted reward 0.071767, actual reward -0.399813
# round 66, predicted reward 0.286481, actual reward 0.283407
# round 67, predicted reward 0.212305, actual reward 0.605432
# round 68, predicted reward 0.275796, actual reward 0.219938
# round 69, predicted reward 0.180638, actual reward -0.026741
# round 70, predicted reward 0.034070, actual reward 0.263150
# round 71, predicted reward 0.182395, actual reward 0.535304
# round 72, predicted reward 0.204637, actual reward 0.078806
# round 73, predicted reward 0.294389, actual reward 0.181139
# round 74, predicted reward 0.215059, actual reward 0.646190
# round 75, predicted reward 0.185285, actual reward 0.348244
# round 76, predicted reward 0.047211, actual reward 0.023036
# round 77, predicted reward 0.022058, actual reward -0.159444
# round 78, predicted reward 0.088689, actual reward 0.504400
# round 79, predicted reward 0.276795, actual reward 0.733609
# round 80, predicted reward 0.145156, actual reward 0.784223
# round 81, predicted reward 0.122842, actual reward 0.414916
# round 82, predicted reward -0.058932, actual reward -0.342845
# round 83, predicted reward 0.079084, actual reward 0.502526
# round 84, predicted reward 0.063992, actual reward 0.247698
# round 85, predicted reward 0.174518, actual reward -0.037865
# round 86, predicted reward 0.042384, actual reward -0.120438
# round 87, predicted reward 0.373943, actual reward 0.573251
# round 88, predicted reward 0.136773, actual reward -0.279112
# round 89, predicted reward 0.086462, actual reward 0.095631
# round 90, predicted reward 0.201468, actual reward 0.236206
# round 91, predicted reward 0.108973, actual reward 0.619990
# round 92, predicted reward 0.240323, actual reward -0.133294
# round 93, predicted reward 0.166364, actual reward 0.050485
# round 94, predicted reward 0.021013, actual reward 0.610933
# round 95, predicted reward -0.084124, actual reward -0.159064
# round 96, predicted reward 0.318828, actual reward 0.648249
# round 97, predicted reward 0.140479, actual reward 0.258465
# round 98, predicted reward 0.022412, actual reward 0.515599
# round 99, predicted reward 0.189306, actual reward 0.128528
# round 100, predicted reward 0.139497, actual reward 0.285891
# round 101, predicted reward 0.201744, actual reward 0.553422
# round 102, predicted reward -0.065720, actual reward -0.419384
# round 103, predicted reward 0.404144, actual reward 0.483058
# round 104, predicted reward 0.014350, actual reward -0.523534
# round 105, predicted reward 0.364339, actual reward 0.313119
# round 106, predicted reward 0.029801, actual reward 0.170971
# round 107, predicted reward 0.016534, actual reward 0.130741
# round 108, predicted reward 0.243398, actual reward -0.162191
# round 109, predicted reward 0.217907, actual reward 0.473410
# round 110, predicted reward 0.195288, actual reward 0.028296
# round 111, predicted reward 0.140991, actual reward 0.606891
# round 112, predicted reward 0.436732, actual reward 0.385227
# round 113, predicted reward 0.100422, actual reward -0.027889
# round 114, predicted reward 0.444474, actual reward -0.136039
# round 115, predicted reward 0.166454, actual reward -0.013003
# round 116, predicted reward 0.229406, actual reward -0.061768
# round 117, predicted reward 0.248091, actual reward 0.710249
# round 118, predicted reward 0.114039, actual reward -0.542130
# round 119, predicted reward 0.150902, actual reward 0.309675
# round 120, predicted reward 0.194015, actual reward 0.531636
# round 121, predicted reward 0.112798, actual reward -0.039244
# round 122, predicted reward 0.467240, actual reward 0.806556
# round 123, predicted reward 0.097339, actual reward -0.350545
# round 124, predicted reward 0.071345, actual reward -0.529921
# round 125, predicted reward 0.614328, actual reward 0.766335
# round 126, predicted reward 0.072011, actual reward -0.068869
# round 127, predicted reward 0.374201, actual reward 0.451073
# round 128, predicted reward 0.327236, actual reward 0.822804
# round 129, predicted reward 0.216752, actual reward 0.225587
# round 130, predicted reward 0.143818, actual reward 0.503099
# round 131, predicted reward 0.099543, actual reward 0.080767
# round 132, predicted reward 0.216971, actual reward 0.070044
# round 133, predicted reward 0.029883, actual reward -0.095629
# round 134, predicted reward 0.210702, actual reward 0.261774
# round 135, predicted reward 0.529813, actual reward 0.161240
# round 136, predicted reward 0.052996, actual reward 0.041415
# round 137, predicted reward 0.028896, actual reward -0.104184
# round 138, predicted reward 0.106733, actual reward 0.472443
# round 139, predicted reward 0.239847, actual reward -0.277122
# round 140, predicted reward 0.273338, actual reward 0.022805
# round 141, predicted reward 0.156507, actual reward 0.232738
# round 142, predicted reward 0.602492, actual reward 0.505589
# round 143, predicted reward 0.435112, actual reward 0.521687
# round 144, predicted reward 0.166616, actual reward 0.281942
# round 145, predicted reward 0.522526, actual reward 0.106056
# round 146, predicted reward 0.054781, actual reward -0.176229
# round 147, predicted reward 0.088639, actual reward -0.218019
# round 148, predicted reward 0.179339, actual reward 0.591964
# round 149, predicted reward 0.012167, actual reward 0.119103
# round 150, predicted reward 0.047657, actual reward 0.161311
# round 151, predicted reward 0.498842, actual reward 0.589868
# round 152, predicted reward 0.562597, actual reward 0.689453
# round 153, predicted reward 0.519010, actual reward 0.619855
# round 154, predicted reward 0.331904, actual reward -0.006165
# round 155, predicted reward 0.170229, actual reward 0.266145
# round 156, predicted reward 0.092881, actual reward -0.262930
# round 157, predicted reward 0.403350, actual reward 0.662577
# round 158, predicted reward 0.152804, actual reward 0.396145
# round 159, predicted reward 0.056459, actual reward 0.448996
# round 160, predicted reward 0.392784, actual reward 0.706085
# round 161, predicted reward 0.073751, actual reward 0.562014
# round 162, predicted reward 0.049605, actual reward -0.443878
# round 163, predicted reward 0.174470, actual reward -0.164901
# round 164, predicted reward 0.400843, actual reward 0.543162
# round 165, predicted reward 0.000000, actual reward -0.388544
# round 166, predicted reward 0.090218, actual reward 0.062722
# round 167, predicted reward 0.181135, actual reward 0.032278
# round 168, predicted reward 0.265377, actual reward 0.283050
# round 169, predicted reward 0.489708, actual reward 0.328180
# round 170, predicted reward 0.239288, actual reward 0.198317
# round 171, predicted reward 0.074986, actual reward -0.319008
# round 172, predicted reward -0.003253, actual reward 0.395092
# round 173, predicted reward 0.110309, actual reward -0.140486
# round 174, predicted reward 0.057206, actual reward 0.627852
# round 175, predicted reward 0.182451, actual reward 0.079743
# round 176, predicted reward 0.192029, actual reward 0.350955
# round 177, predicted reward 0.086007, actual reward -0.284964
# round 178, predicted reward 0.482227, actual reward 0.552437
# round 179, predicted reward 0.067861, actual reward 0.417130
# round 180, predicted reward 0.537107, actual reward 0.624560
# round 181, predicted reward 0.333129, actual reward 0.189623
# round 182, predicted reward 0.058767, actual reward 0.136554
# round 183, predicted reward 0.172690, actual reward 0.673617
# round 184, predicted reward -0.025577, actual reward 0.125427
# round 185, predicted reward 0.125811, actual reward 0.435444
# round 186, predicted reward 0.373182, actual reward 0.215454
# round 187, predicted reward 0.517753, actual reward 0.424835
# round 188, predicted reward 0.252063, actual reward 0.577703
# round 189, predicted reward 0.398634, actual reward 0.528793
# round 190, predicted reward 0.270115, actual reward 0.637677
# round 191, predicted reward -0.045544, actual reward -0.236118
# round 192, predicted reward 0.005826, actual reward 0.081109
# round 193, predicted reward 0.354627, actual reward 0.636078
# round 194, predicted reward 0.179965, actual reward -0.242178
# round 195, predicted reward 0.391576, actual reward 0.464279
# round 196, predicted reward 0.203380, actual reward -0.046065
# round 197, predicted reward 0.166393, actual reward 0.221883
# round 198, predicted reward 0.061029, actual reward -0.509061
# round 199, predicted reward 0.082733, actual reward -0.477289
# round 200, predicted reward 0.035951, actual reward -0.365391
# round 201, predicted reward 0.425326, actual reward 0.788271
# round 202, predicted reward 0.077008, actual reward -0.100335
# round 203, predicted reward 0.254028, actual reward -0.006192
# round 204, predicted reward 0.059452, actual reward -0.405408
# round 205, predicted reward 0.229591, actual reward 0.315102
# round 206, predicted reward 0.128887, actual reward -0.036526
# round 207, predicted reward 0.198043, actual reward 0.400678
# round 208, predicted reward 0.198336, actual reward 0.317568
# round 209, predicted reward 0.207098, actual reward 0.578090
# round 210, predicted reward 0.052718, actual reward 0.055673
# round 211, predicted reward 0.046473, actual reward 0.233516
# round 212, predicted reward 0.338321, actual reward 0.562376
# round 213, predicted reward 0.310235, actual reward 0.521236
# round 214, predicted reward 0.341489, actual reward 0.399070
# round 215, predicted reward 0.080620, actual reward -0.144211
# round 216, predicted reward 0.156807, actual reward 0.410451
# round 217, predicted reward 0.121061, actual reward 0.020625
# round 218, predicted reward 0.024258, actual reward -0.205689
# round 219, predicted reward 0.549254, actual reward 0.798979
# round 220, predicted reward 0.258928, actual reward 0.484320
# round 221, predicted reward 0.121258, actual reward 0.148253
# round 222, predicted reward 0.173327, actual reward 0.267085
# round 223, predicted reward 0.377964, actual reward 0.415303
# round 224, predicted reward 0.441034, actual reward 0.173862
# round 225, predicted reward 0.209531, actual reward 0.490142
# round 226, predicted reward 0.195599, actual reward 0.633323
# round 227, predicted reward 0.170371, actual reward 0.386886
# round 228, predicted reward 0.111038, actual reward 0.342071
# round 229, predicted reward 0.179251, actual reward 0.371143
# round 230, predicted reward 0.470250, actual reward 0.280565
# round 231, predicted reward 0.726074, actual reward 0.609541
# round 232, predicted reward -0.011460, actual reward -0.393929
# round 233, predicted reward -0.006273, actual reward -0.165335
# round 234, predicted reward 0.051892, actual reward -0.448374
# round 235, predicted reward 0.272202, actual reward 0.152968
# round 236, predicted reward 0.090025, actual reward 0.203114
# round 237, predicted reward 0.486134, actual reward 0.520957
# round 238, predicted reward 0.295464, actual reward 0.147555
# round 239, predicted reward 0.232647, actual reward 0.338809
# round 240, predicted reward 0.538699, actual reward 0.603589
# round 241, predicted reward 0.367330, actual reward 0.138976
# round 242, predicted reward 0.355800, actual reward 0.709897
# round 243, predicted reward 0.602865, actual reward 0.528719
# round 244, predicted reward 0.608241, actual reward 0.392263
# round 245, predicted reward 0.670421, actual reward 0.481542
# round 246, predicted reward 0.463192, actual reward 0.692690
# round 247, predicted reward 0.094209, actual reward -0.097106
# round 248, predicted reward 0.141287, actual reward -0.087828
# round 249, predicted reward 0.165442, actual reward 0.262520
# round 250, predicted reward 0.291565, actual reward 0.163249
# round 251, predicted reward 0.231916, actual reward 0.425850
# round 252, predicted reward 0.202371, actual reward 0.382835
# round 253, predicted reward 0.018925, actual reward -0.056137
# round 254, predicted reward 0.544375, actual reward 0.607342
# round 255, predicted reward 0.311503, actual reward 0.629310
# round 256, predicted reward 0.235687, actual reward 0.385434
# round 257, predicted reward 0.745565, actual reward 0.656156
# round 258, predicted reward 0.099881, actual reward 0.349702
# round 259, predicted reward 0.513851, actual reward 0.461626
# round 260, predicted reward 0.388409, actual reward 0.530638
# round 261, predicted reward 0.097050, actual reward 0.067029
# round 262, predicted reward 0.060681, actual reward -0.119614
# round 263, predicted reward 0.641950, actual reward 0.683765
# round 264, predicted reward 0.158063, actual reward 0.449949
# round 265, predicted reward 0.369153, actual reward 0.699706
# round 266, predicted reward 0.388425, actual reward 0.606338
# round 267, predicted reward 0.428014, actual reward 0.547497
# round 268, predicted reward 0.346310, actual reward 0.582500
# round 269, predicted reward 0.261619, actual reward 0.428387
# round 270, predicted reward 0.138143, actual reward 0.275679
# round 271, predicted reward 0.337423, actual reward 0.329969
# round 272, predicted reward 0.285886, actual reward 0.597112
# round 273, predicted reward 0.476334, actual reward 0.290681
# round 274, predicted reward 0.280963, actual reward 0.529912
# round 275, predicted reward 0.478536, actual reward 0.473168
# round 276, predicted reward 0.252998, actual reward 0.579059
# round 277, predicted reward 0.553184, actual reward 0.590317
# round 278, predicted reward 0.325369, actual reward 0.524374
# round 279, predicted reward 0.052510, actual reward 0.069504
# round 280, predicted reward 0.045158, actual reward -0.197453
# round 281, predicted reward 0.277206, actual reward 0.119773
# round 282, predicted reward 0.171546, actual reward -0.189056
# round 283, predicted reward 0.217785, actual reward 0.473670
# round 284, predicted reward 0.237471, actual reward 0.519594
# round 285, predicted reward 0.296352, actual reward 0.489117
# round 286, predicted reward 0.602327, actual reward 0.569819
# round 287, predicted reward 0.077733, actual reward 0.206445
# round 288, predicted reward 0.243608, actual reward 0.080122
# round 289, predicted reward 0.739219, actual reward 0.700681
# round 290, predicted reward 0.427551, actual reward 0.415724
# round 291, predicted reward 0.485395, actual reward 0.386393
# round 292, predicted reward -0.054618, actual reward -0.609885
# round 293, predicted reward 0.344622, actual reward 0.408795
# round 294, predicted reward 0.394699, actual reward 0.699037
# round 295, predicted reward 0.102950, actual reward 0.299378
# round 296, predicted reward -0.007332, actual reward -0.328179
# round 297, predicted reward 0.825636, actual reward 0.690174
# round 298, predicted reward 0.512652, actual reward 0.437860
# round 299, predicted reward 0.896711, actual reward 0.746879
# round 300, predicted reward 0.160261, actual reward 0.524058
# round 301, predicted reward 0.960720, actual reward 0.825085
# round 302, predicted reward -0.044614, actual reward -0.421719
# round 303, predicted reward 0.211535, actual reward 0.318759
# round 304, predicted reward 0.402926, actual reward 0.389835
# round 305, predicted reward 0.560345, actual reward 0.587269
# round 306, predicted reward 0.474391, actual reward 0.623295
# round 307, predicted reward 0.310300, actual reward 0.503637
# round 308, predicted reward 0.325661, actual reward 0.491110
# round 309, predicted reward -0.122650, actual reward -0.107679
# round 310, predicted reward 0.306985, actual reward 0.439540
# round 311, predicted reward 0.153053, actual reward 0.222338
# round 312, predicted reward 0.500340, actual reward 0.515855
# round 313, predicted reward 0.310999, actual reward 0.166405
# round 314, predicted reward -0.046827, actual reward -0.045311
# round 315, predicted reward 0.327031, actual reward 0.551954
# round 316, predicted reward 0.339651, actual reward 0.543184
# round 317, predicted reward 0.097119, actual reward 0.107483
# round 318, predicted reward 0.713351, actual reward 0.769200
# round 319, predicted reward 0.080909, actual reward 0.020490
# round 320, predicted reward 0.214811, actual reward 0.296952
# round 321, predicted reward -0.018936, actual reward -0.105975
# round 322, predicted reward 0.375522, actual reward 0.460681
# round 323, predicted reward 0.049231, actual reward 0.247885
# round 324, predicted reward 0.985488, actual reward 0.750239
# round 325, predicted reward 0.072618, actual reward -0.074999
# round 326, predicted reward 0.666495, actual reward 0.533951
# round 327, predicted reward 0.272423, actual reward 0.364107
# round 328, predicted reward 0.369080, actual reward 0.462401
# round 329, predicted reward 0.457630, actual reward 0.524245
# round 330, predicted reward 0.254755, actual reward 0.438794
# round 331, predicted reward 0.384487, actual reward 0.552235
# round 332, predicted reward 0.701895, actual reward 0.709138
# round 333, predicted reward 0.843626, actual reward 0.795873
# round 334, predicted reward 0.508479, actual reward 0.651304
# round 335, predicted reward 0.458447, actual reward 0.595835
# round 336, predicted reward 0.117658, actual reward 0.066800
# round 337, predicted reward 0.722744, actual reward 0.682088
# round 338, predicted reward 0.565761, actual reward 0.661686
# round 339, predicted reward 0.135004, actual reward 0.123794
# round 340, predicted reward 0.100868, actual reward 0.196318
# round 341, predicted reward 0.523320, actual reward 0.499128
# round 342, predicted reward 0.488991, actual reward 0.473392
# round 343, predicted reward 0.164962, actual reward 0.300136
# round 344, predicted reward 0.282862, actual reward 0.374849
# round 345, predicted reward 0.401088, actual reward 0.593046
# round 346, predicted reward 0.450914, actual reward 0.407830
# round 347, predicted reward 0.358532, actual reward 0.350926
# round 348, predicted reward 0.702658, actual reward 0.628023
# round 349, predicted reward -0.236290, actual reward -0.806331
# round 350, predicted reward 0.181430, actual reward 0.279432
# round 351, predicted reward 0.251295, actual reward 0.507840
# round 352, predicted reward 0.627184, actual reward 0.673592
# round 353, predicted reward 0.382246, actual reward 0.494780
# round 354, predicted reward 0.573324, actual reward 0.598203
# round 355, predicted reward 0.339805, actual reward 0.609083
# round 356, predicted reward 0.283772, actual reward 0.316741
# round 357, predicted reward 0.859054, actual reward 0.805617
# round 358, predicted reward 0.406905, actual reward 0.609549
# round 359, predicted reward 0.632144, actual reward 0.766960
# round 360, predicted reward 0.533183, actual reward 0.547151
# round 361, predicted reward 0.728290, actual reward 0.655315
# round 362, predicted reward -0.022312, actual reward -0.019718
# round 363, predicted reward 0.189835, actual reward 0.492497
# round 364, predicted reward 0.787076, actual reward 0.772809
# round 365, predicted reward 0.574502, actual reward 0.489113
# round 366, predicted reward 0.164075, actual reward 0.373244
# round 367, predicted reward 0.181628, actual reward 0.256723
# round 368, predicted reward 0.009854, actual reward 0.096755
# round 369, predicted reward 0.536426, actual reward 0.506299
# round 370, predicted reward 0.220448, actual reward 0.382586
# round 371, predicted reward 0.471463, actual reward 0.544224
# round 372, predicted reward 0.749063, actual reward 0.702230
# round 373, predicted reward 0.470294, actual reward 0.448961
# round 374, predicted reward 0.696151, actual reward 0.675492
# round 375, predicted reward 0.510888, actual reward 0.459648
# round 376, predicted reward 0.358846, actual reward 0.535568
# round 377, predicted reward 0.091314, actual reward 0.231524
# round 378, predicted reward 0.548265, actual reward 0.710945
# round 379, predicted reward 0.158313, actual reward -0.029497
# round 380, predicted reward -0.058974, actual reward -0.292156
# round 381, predicted reward 0.712143, actual reward 0.745997
# round 382, predicted reward 0.236938, actual reward 0.119031
# round 383, predicted reward 0.568357, actual reward 0.509433
# round 384, predicted reward 0.462662, actual reward 0.422743
# round 385, predicted reward 0.424886, actual reward 0.562153
# round 386, predicted reward 0.112019, actual reward 0.071731
# round 387, predicted reward 0.733641, actual reward 0.772850
# round 388, predicted reward 0.626197, actual reward 0.636241
# round 389, predicted reward 0.635768, actual reward 0.607191
# round 390, predicted reward 0.592408, actual reward 0.559376
# round 391, predicted reward 0.290653, actual reward 0.202147
# round 392, predicted reward 0.482695, actual reward 0.595431
# round 393, predicted reward 0.681154, actual reward 0.544005
# round 394, predicted reward 0.095656, actual reward 0.111418
# round 395, predicted reward 0.460270, actual reward 0.566205
# round 396, predicted reward 0.532984, actual reward 0.465233
# round 397, predicted reward 0.612331, actual reward 0.714554
# round 398, predicted reward 0.351827, actual reward 0.355113
# round 399, predicted reward 0.878127, actual reward 0.758635
# round 400, predicted reward 0.661778, actual reward 0.613545
# round 401, predicted reward 0.297657, actual reward 0.286354
# round 402, predicted reward 0.728738, actual reward 0.636490
# round 403, predicted reward 0.285186, actual reward 0.336492
# round 404, predicted reward 0.414304, actual reward 0.506396
# round 405, predicted reward 0.253701, actual reward 0.367361
# round 406, predicted reward 0.053356, actual reward 0.038772
# round 407, predicted reward 0.491090, actual reward 0.504188
# round 408, predicted reward 0.291050, actual reward 0.263223
# round 409, predicted reward 0.175119, actual reward 0.203670
# round 410, predicted reward 0.483006, actual reward 0.608436
# round 411, predicted reward -0.026676, actual reward -0.069620
# round 412, predicted reward 0.129184, actual reward 0.339280
# round 413, predicted reward 0.231739, actual reward 0.405486
# round 414, predicted reward 0.905291, actual reward 0.734816
# round 415, predicted reward 0.089860, actual reward 0.052743
# round 416, predicted reward -0.013133, actual reward -0.187502
# round 417, predicted reward 0.663119, actual reward 0.703088
# round 418, predicted reward 0.103086, actual reward 0.179896
# round 419, predicted reward 0.513736, actual reward 0.456838
# round 420, predicted reward 0.283911, actual reward 0.297858
# round 421, predicted reward 0.396320, actual reward 0.407819
# round 422, predicted reward 0.051931, actual reward 0.135412
# round 423, predicted reward -0.090724, actual reward -0.388370
# round 424, predicted reward -0.000221, actual reward 0.202326
# round 425, predicted reward 0.095830, actual reward 0.216845
# round 426, predicted reward -0.040192, actual reward 0.035815
# round 427, predicted reward 0.704468, actual reward 0.733014
# round 428, predicted reward 0.559639, actual reward 0.551461
# round 429, predicted reward 0.237193, actual reward 0.398641
# round 430, predicted reward 0.227594, actual reward 0.306206
# round 431, predicted reward 0.242684, actual reward 0.409239
# round 432, predicted reward 0.163748, actual reward 0.393258
# round 433, predicted reward 0.125686, actual reward 0.144518
# round 434, predicted reward 0.558859, actual reward 0.592720
# round 435, predicted reward 0.294139, actual reward 0.576060
# round 436, predicted reward 0.678621, actual reward 0.618391
# round 437, predicted reward 0.513172, actual reward 0.535569
# round 438, predicted reward 0.485777, actual reward 0.444043
# round 439, predicted reward 0.087081, actual reward 0.208045
# round 440, predicted reward 0.467931, actual reward 0.652372
# round 441, predicted reward 0.466897, actual reward 0.603752
# round 442, predicted reward 0.625871, actual reward 0.711495
# round 443, predicted reward 0.374540, actual reward 0.632828
# round 444, predicted reward 0.000000, actual reward -0.435576
# round 445, predicted reward 0.384254, actual reward 0.434514
# round 446, predicted reward 0.657915, actual reward 0.636578
# round 447, predicted reward 0.177526, actual reward 0.131097
# round 448, predicted reward 0.714397, actual reward 0.620344
# round 449, predicted reward 0.531286, actual reward 0.545901
# round 450, predicted reward 0.543702, actual reward 0.508894
# round 451, predicted reward 0.261578, actual reward 0.424762
# round 452, predicted reward 0.085629, actual reward 0.104987
# round 453, predicted reward 0.633721, actual reward 0.591006
# round 454, predicted reward 0.923504, actual reward 0.809851
# round 455, predicted reward 0.077493, actual reward -0.114694
# round 456, predicted reward 0.435135, actual reward 0.478145
# round 457, predicted reward 0.050206, actual reward -0.014185
# round 458, predicted reward 0.046194, actual reward -0.036608
# round 459, predicted reward 0.142220, actual reward 0.210214
# round 460, predicted reward 0.534923, actual reward 0.615374
# round 461, predicted reward 0.619065, actual reward 0.589684
# round 462, predicted reward 0.578056, actual reward 0.586928
# round 463, predicted reward 0.661628, actual reward 0.668814
# round 464, predicted reward 0.391141, actual reward 0.521495
# round 465, predicted reward -0.059002, actual reward -0.066752
# round 466, predicted reward 0.498014, actual reward 0.530247
# round 467, predicted reward 0.256050, actual reward 0.218355
# round 468, predicted reward 0.733182, actual reward 0.711559
# round 469, predicted reward 0.748036, actual reward 0.770647
# round 470, predicted reward 0.042474, actual reward -0.129310
# round 471, predicted reward 0.436959, actual reward 0.536143
# round 472, predicted reward 0.332683, actual reward 0.367252
# round 473, predicted reward 1.039930, actual reward 0.821732
# round 474, predicted reward 0.505601, actual reward 0.594681
# round 475, predicted reward 0.600865, actual reward 0.522010
# round 476, predicted reward 0.264843, actual reward 0.419005
# round 477, predicted reward 0.263951, actual reward 0.405046
# round 478, predicted reward 0.265490, actual reward 0.414735
# round 479, predicted reward 0.019597, actual reward -0.080622
# round 480, predicted reward -0.011409, actual reward -0.227419
# round 481, predicted reward 0.314222, actual reward 0.420071
# round 482, predicted reward 0.533686, actual reward 0.677338
# round 483, predicted reward -0.009839, actual reward -0.092797
# round 484, predicted reward 0.897781, actual reward 0.790278
# round 485, predicted reward 0.020302, actual reward 0.124948
# round 486, predicted reward 0.096588, actual reward 0.102448
# round 487, predicted reward 0.726571, actual reward 0.688596
# round 488, predicted reward 0.227421, actual reward 0.303392
# round 489, predicted reward 0.252468, actual reward 0.428244
# round 490, predicted reward 0.619843, actual reward 0.549624
# round 491, predicted reward 0.381247, actual reward 0.428449
# round 492, predicted reward 0.435501, actual reward 0.377084
# round 493, predicted reward 0.367858, actual reward 0.557622
# round 494, predicted reward 0.408454, actual reward 0.341925
# round 495, predicted reward 0.566384, actual reward 0.594443
# round 496, predicted reward 0.279005, actual reward 0.364878
# round 497, predicted reward 0.152468, actual reward 0.289919
# round 498, predicted reward 0.696601, actual reward 0.668807
# round 499, predicted reward 0.631266, actual reward 0.645642
# round 500, predicted reward 0.921769, actual reward 0.794256
# round 501, predicted reward 0.796863, actual reward 0.737820
# round 502, predicted reward 0.168873, actual reward 0.125287
# round 503, predicted reward 0.591538, actual reward 0.682880
# round 504, predicted reward 0.682688, actual reward 0.636195
# round 505, predicted reward 0.107684, actual reward -0.002163
# round 506, predicted reward -0.043226, actual reward -0.030779
# round 507, predicted reward 0.515395, actual reward 0.597886
# round 508, predicted reward 0.392454, actual reward 0.494452
# round 509, predicted reward 0.592005, actual reward 0.651143
# round 510, predicted reward 1.111252, actual reward 0.870011
# round 511, predicted reward 0.511530, actual reward 0.533419
# round 512, predicted reward 0.384683, actual reward 0.376741
# round 513, predicted reward 0.383912, actual reward 0.475573
# round 514, predicted reward 0.117520, actual reward -0.049394
# round 515, predicted reward 0.962328, actual reward 0.762550
# round 516, predicted reward 0.633751, actual reward 0.620805
# round 517, predicted reward 0.438477, actual reward 0.474150
# round 518, predicted reward 0.469868, actual reward 0.496337
# round 519, predicted reward 0.028830, actual reward 0.085684
# round 520, predicted reward 0.076818, actual reward 0.026600
# round 521, predicted reward 0.439890, actual reward 0.474849
# round 522, predicted reward 0.322874, actual reward 0.332619
# round 523, predicted reward 0.217450, actual reward 0.167085
# round 524, predicted reward 0.027509, actual reward 0.234605
# round 525, predicted reward 0.449639, actual reward 0.597546
# round 526, predicted reward 0.348736, actual reward 0.452627
# round 527, predicted reward 0.235698, actual reward 0.275488
# round 528, predicted reward 0.787773, actual reward 0.755592
# round 529, predicted reward -0.027793, actual reward -0.231720
# round 530, predicted reward 0.683835, actual reward 0.611357
# round 531, predicted reward 0.360076, actual reward 0.368377
# round 532, predicted reward 0.321384, actual reward 0.457782
# round 533, predicted reward 0.031914, actual reward -0.159482
# round 534, predicted reward 0.380341, actual reward 0.518893
# round 535, predicted reward 0.977302, actual reward 0.833598
# round 536, predicted reward 0.722383, actual reward 0.639006
# round 537, predicted reward 0.698965, actual reward 0.623073
# round 538, predicted reward 0.273177, actual reward 0.315778
# round 539, predicted reward 0.161124, actual reward 0.227294
# round 540, predicted reward 0.583206, actual reward 0.604612
# round 541, predicted reward 0.435098, actual reward 0.485712
# round 542, predicted reward 0.501163, actual reward 0.511950
# round 543, predicted reward 0.446693, actual reward 0.486677
# round 544, predicted reward 0.135996, actual reward -0.004172
# round 545, predicted reward 0.538029, actual reward 0.645771
# round 546, predicted reward 0.100924, actual reward 0.266055
# round 547, predicted reward 0.306452, actual reward 0.350508
# round 548, predicted reward 0.457306, actual reward 0.485231
# round 549, predicted reward 0.761445, actual reward 0.703118
# round 550, predicted reward 0.202619, actual reward 0.332782
# round 551, predicted reward 0.269526, actual reward 0.398585
# round 552, predicted reward 0.802925, actual reward 0.768954
# round 553, predicted reward 0.732599, actual reward 0.716563
# round 554, predicted reward 0.083008, actual reward 0.057218
# round 555, predicted reward 0.531508, actual reward 0.615521
# round 556, predicted reward 0.485967, actual reward 0.591817
# round 557, predicted reward 0.371813, actual reward 0.446169
# round 558, predicted reward 0.107299, actual reward 0.032907
# round 559, predicted reward 0.631564, actual reward 0.667391
# round 560, predicted reward 0.222043, actual reward 0.347594
# round 561, predicted reward 0.232735, actual reward 0.355076
# round 562, predicted reward 0.316525, actual reward 0.409224
# round 563, predicted reward 0.995848, actual reward 0.808251
# round 564, predicted reward 0.340707, actual reward 0.476365
# round 565, predicted reward 0.148999, actual reward 0.247484
# round 566, predicted reward 0.316490, actual reward 0.475739
# round 567, predicted reward 0.530386, actual reward 0.571996
# round 568, predicted reward 0.394831, actual reward 0.474701
# round 569, predicted reward 0.116550, actual reward 0.029270
# round 570, predicted reward 0.427232, actual reward 0.481535
# round 571, predicted reward 0.459458, actual reward 0.511060
# round 572, predicted reward -0.037458, actual reward 0.084666
# round 573, predicted reward 0.599081, actual reward 0.606850
# round 574, predicted reward 0.493879, actual reward 0.560605
# round 575, predicted reward -0.255801, actual reward -0.087768
# round 576, predicted reward 0.436045, actual reward 0.520369
# round 577, predicted reward 0.439902, actual reward 0.520650
# round 578, predicted reward 0.486140, actual reward 0.533804
# round 579, predicted reward 0.004238, actual reward 0.102479
# round 580, predicted reward 0.292229, actual reward 0.406626
# round 581, predicted reward 0.232120, actual reward 0.221486
# round 582, predicted reward 0.810804, actual reward 0.769595
# round 583, predicted reward 0.264575, actual reward 0.338334
# round 584, predicted reward 0.066629, actual reward -0.131266
# round 585, predicted reward 0.234698, actual reward 0.363478
# round 586, predicted reward 0.445740, actual reward 0.495049
# round 587, predicted reward 0.151254, actual reward -0.028219
# round 588, predicted reward 0.473649, actual reward 0.562714
# round 589, predicted reward 0.200283, actual reward 0.105535
# round 590, predicted reward 0.417475, actual reward 0.429852
# round 591, predicted reward 0.766036, actual reward 0.720337
# round 592, predicted reward 0.556795, actual reward 0.622360
# round 593, predicted reward 0.507161, actual reward 0.494179
# round 594, predicted reward 0.262398, actual reward 0.258428
# round 595, predicted reward 0.390244, actual reward 0.488218
# round 596, predicted reward 0.326549, actual reward 0.391176
# round 597, predicted reward -0.025018, actual reward -0.355157
# round 598, predicted reward 0.467373, actual reward 0.499567
# round 599, predicted reward 0.456271, actual reward 0.533672
# round 600, predicted reward 0.496755, actual reward 0.563314
# round 601, predicted reward 0.594596, actual reward 0.613863
# round 602, predicted reward 0.361543, actual reward 0.369770
# round 603, predicted reward 0.455112, actual reward 0.398275
# round 604, predicted reward 0.027361, actual reward -0.055323
# round 605, predicted reward 0.483988, actual reward 0.595639
# round 606, predicted reward 0.448038, actual reward 0.498875
# round 607, predicted reward 0.072770, actual reward 0.142500
# round 608, predicted reward 0.281113, actual reward 0.311931
# round 609, predicted reward 0.033332, actual reward 0.113785
# round 610, predicted reward 0.378508, actual reward 0.409090
# round 611, predicted reward -0.027333, actual reward -0.474099
# round 612, predicted reward 0.670670, actual reward 0.725152
# round 613, predicted reward 0.478651, actual reward 0.528549
# round 614, predicted reward 0.225078, actual reward 0.252763
# round 615, predicted reward 0.000000, actual reward -0.371616
# round 616, predicted reward 0.076339, actual reward 0.200047
# round 617, predicted reward -0.014866, actual reward -0.005918
# round 618, predicted reward 0.411334, actual reward 0.440323
# round 619, predicted reward 0.334114, actual reward 0.425408
# round 620, predicted reward 0.013662, actual reward 0.026799
# round 621, predicted reward 0.321605, actual reward 0.360825
# round 622, predicted reward 0.488312, actual reward 0.570820
# round 623, predicted reward 0.048493, actual reward -0.244878
# round 624, predicted reward 0.219351, actual reward 0.236488
# round 625, predicted reward 0.617349, actual reward 0.669308
# round 626, predicted reward -0.183708, actual reward -0.195771
# round 627, predicted reward -0.154934, actual reward -0.334932
# round 628, predicted reward -0.043246, actual reward -0.000765
# round 629, predicted reward 0.622315, actual reward 0.651511
# round 630, predicted reward 0.428861, actual reward 0.511007
# round 631, predicted reward 0.487055, actual reward 0.560998
# round 632, predicted reward 0.619462, actual reward 0.655002
# round 633, predicted reward 0.066152, actual reward -0.070149
# round 634, predicted reward 0.617089, actual reward 0.629443
# round 635, predicted reward 0.373245, actual reward 0.458503
# round 636, predicted reward 0.463502, actual reward 0.487112
# round 637, predicted reward 0.141041, actual reward 0.099840
# round 638, predicted reward 0.644739, actual reward 0.647063
# round 639, predicted reward 0.614275, actual reward 0.656895
# round 640, predicted reward 0.551767, actual reward 0.580205
# round 641, predicted reward 0.009316, actual reward -0.428356
# round 642, predicted reward 0.717993, actual reward 0.694060
# round 643, predicted reward 0.193966, actual reward 0.271793
# round 644, predicted reward 0.205133, actual reward 0.336408
# round 645, predicted reward 0.874152, actual reward 0.795141
# round 646, predicted reward 0.198410, actual reward 0.330255
# round 647, predicted reward 0.280062, actual reward 0.283823
# round 648, predicted reward 0.479003, actual reward 0.472437
# round 649, predicted reward 0.235783, actual reward 0.235073
# round 650, predicted reward 0.847260, actual reward 0.764624
# round 651, predicted reward 0.416237, actual reward 0.397703
# round 652, predicted reward 0.212746, actual reward 0.243228
# round 653, predicted reward 0.449150, actual reward 0.473349
# round 654, predicted reward 0.513607, actual reward 0.493223
# round 655, predicted reward 0.707522, actual reward 0.708867
# round 656, predicted reward 0.805019, actual reward 0.752650
# round 657, predicted reward 0.350823, actual reward 0.343822
# round 658, predicted reward 0.311875, actual reward 0.282145
# round 659, predicted reward 0.934236, actual reward 0.771807
# round 660, predicted reward 0.830339, actual reward 0.769696
# round 661, predicted reward 0.713293, actual reward 0.680906
# round 662, predicted reward 0.401114, actual reward 0.403960
# round 663, predicted reward 0.058292, actual reward -0.046334
# round 664, predicted reward 0.596932, actual reward 0.633366
# round 665, predicted reward 0.389465, actual reward 0.433143
# round 666, predicted reward 0.383639, actual reward 0.362422
# round 667, predicted reward 0.496770, actual reward 0.546703
# round 668, predicted reward 0.304283, actual reward 0.377655
# round 669, predicted reward 0.198344, actual reward 0.247152
# round 670, predicted reward 0.380605, actual reward 0.441350
# round 671, predicted reward 0.296420, actual reward 0.357346
# round 672, predicted reward 0.499560, actual reward 0.528522
# round 673, predicted reward 0.195525, actual reward 0.315502
# round 674, predicted reward 0.399969, actual reward 0.409588
# round 675, predicted reward 0.041832, actual reward 0.015737
# round 676, predicted reward 0.423225, actual reward 0.535882
# round 677, predicted reward 0.447484, actual reward 0.521781
# round 678, predicted reward 0.700296, actual reward 0.665264
# round 679, predicted reward 0.099684, actual reward -0.028036
# round 680, predicted reward -0.207816, actual reward -0.058278
# round 681, predicted reward 0.195965, actual reward 0.289752
# round 682, predicted reward 0.243498, actual reward 0.422708
# round 683, predicted reward 0.125353, actual reward 0.248406
# round 684, predicted reward 0.461946, actual reward 0.546121
# round 685, predicted reward 0.821796, actual reward 0.743088
# round 686, predicted reward 0.098373, actual reward -0.199455
# round 687, predicted reward 0.189753, actual reward 0.278024
# round 688, predicted reward -0.036481, actual reward -0.197437
# round 689, predicted reward 0.262157, actual reward 0.354343
# round 690, predicted reward 0.372192, actual reward 0.458307
# round 691, predicted reward 0.533689, actual reward 0.508314
# round 692, predicted reward 0.857646, actual reward 0.747684
# round 693, predicted reward 0.634467, actual reward 0.668809
# round 694, predicted reward 0.559026, actual reward 0.531132
# round 695, predicted reward 0.772329, actual reward 0.741979
# round 696, predicted reward 0.524502, actual reward 0.524333
# round 697, predicted reward 0.351023, actual reward 0.394901
# round 698, predicted reward 0.773416, actual reward 0.727191
# round 699, predicted reward 0.141093, actual reward 0.277956
# round 700, predicted reward 0.501898, actual reward 0.558607
# round 701, predicted reward -0.069208, actual reward -0.294405
# round 702, predicted reward 0.111761, actual reward 0.037323
# round 703, predicted reward -0.072851, actual reward -0.152656
# round 704, predicted reward 0.517629, actual reward 0.566054
# round 705, predicted reward 0.072960, actual reward 0.128693
# round 706, predicted reward 0.090295, actual reward 0.045181
# round 707, predicted reward 0.652873, actual reward 0.727567
# round 708, predicted reward 0.045205, actual reward -0.019041
# round 709, predicted reward 0.366551, actual reward 0.437704
# round 710, predicted reward 0.491728, actual reward 0.559547
# round 711, predicted reward 0.719747, actual reward 0.723537
# round 712, predicted reward -0.018278, actual reward -0.299248
# round 713, predicted reward 0.045180, actual reward -0.416628
# round 714, predicted reward 0.027569, actual reward -0.010792
# round 715, predicted reward 0.341611, actual reward 0.368877
# round 716, predicted reward -0.096415, actual reward -0.570505
# round 717, predicted reward 0.662193, actual reward 0.692643
# round 718, predicted reward 0.484901, actual reward 0.538769
# round 719, predicted reward 0.431998, actual reward 0.525871
# round 720, predicted reward 0.500611, actual reward 0.538692
# round 721, predicted reward -0.065916, actual reward -0.331607
# round 722, predicted reward 0.055307, actual reward 0.106041
# round 723, predicted reward -0.029323, actual reward -0.347656
# round 724, predicted reward 0.053921, actual reward -0.230957
# round 725, predicted reward 0.074020, actual reward 0.019303
# round 726, predicted reward 0.766813, actual reward 0.744695
# round 727, predicted reward 0.349473, actual reward 0.474076
# round 728, predicted reward 0.286477, actual reward 0.350065
# round 729, predicted reward 0.579185, actual reward 0.595661
# round 730, predicted reward 0.770551, actual reward 0.748806
# round 731, predicted reward 0.622318, actual reward 0.687232
# round 732, predicted reward 0.492844, actual reward 0.600174
# round 733, predicted reward 0.575551, actual reward 0.568433
# round 734, predicted reward 0.444009, actual reward 0.448957
# round 735, predicted reward 0.559543, actual reward 0.566301
# round 736, predicted reward 0.028165, actual reward -0.040859
# round 737, predicted reward 0.251634, actual reward 0.388472
# round 738, predicted reward 0.125943, actual reward 0.242887
# round 739, predicted reward -0.137468, actual reward -0.497246
# round 740, predicted reward 0.562334, actual reward 0.598594
# round 741, predicted reward 0.322406, actual reward 0.465523
# round 742, predicted reward -0.011793, actual reward -0.365529
# round 743, predicted reward 0.618434, actual reward 0.653644
# round 744, predicted reward 0.415730, actual reward 0.422199
# round 745, predicted reward 0.203450, actual reward 0.301279
# round 746, predicted reward 0.436288, actual reward 0.445784
# round 747, predicted reward 0.796911, actual reward 0.762774
# round 748, predicted reward 0.428696, actual reward 0.485307
# round 749, predicted reward 1.042792, actual reward 0.835518
# round 750, predicted reward 0.553639, actual reward 0.625673
# round 751, predicted reward 0.597435, actual reward 0.593691
# round 752, predicted reward 0.434231, actual reward 0.440440
# round 753, predicted reward 0.659274, actual reward 0.645619
# round 754, predicted reward 0.384591, actual reward 0.455418
# round 755, predicted reward 0.209579, actual reward 0.263313
# round 756, predicted reward 0.504654, actual reward 0.588818
# round 757, predicted reward -0.022876, actual reward -0.154713
# round 758, predicted reward 0.536617, actual reward 0.469725
# round 759, predicted reward 0.409836, actual reward 0.481975
# round 760, predicted reward 0.205713, actual reward 0.211709
# round 761, predicted reward 0.326815, actual reward 0.332785
# round 762, predicted reward 0.610085, actual reward 0.629030
# round 763, predicted reward 0.685297, actual reward 0.649920
# round 764, predicted reward 0.460440, actual reward 0.513095
# round 765, predicted reward 0.488555, actual reward 0.544059
# round 766, predicted reward 0.397211, actual reward 0.409258
# round 767, predicted reward 0.537093, actual reward 0.587122
# round 768, predicted reward -0.098719, actual reward -0.172550
# round 769, predicted reward 0.068441, actual reward 0.127100
# round 770, predicted reward 0.110896, actual reward 0.276907
# round 771, predicted reward 0.166191, actual reward 0.098208
# round 772, predicted reward 0.633076, actual reward 0.645981
# round 773, predicted reward 0.310974, actual reward 0.360305
# round 774, predicted reward 0.532460, actual reward 0.554170
# round 775, predicted reward 0.834754, actual reward 0.731407
# round 776, predicted reward 0.462073, actual reward 0.482797
# round 777, predicted reward 0.840732, actual reward 0.764234
# round 778, predicted reward 0.577203, actual reward 0.611526
# round 779, predicted reward 0.037790, actual reward 0.059547
# round 780, predicted reward 0.732320, actual reward 0.679258
# round 781, predicted reward 0.345153, actual reward 0.334646
# round 782, predicted reward 0.248704, actual reward 0.331288
# round 783, predicted reward 0.199994, actual reward 0.196366
# round 784, predicted reward 0.247612, actual reward 0.159406
# ...
# round 1743, predicted reward 0.035354, actual reward -0.114856
# round 1744, predicted reward 0.679691, actual reward 0.647410
# round 1745, predicted reward 0.185877, actual reward 0.266969
# round 1746, predicted reward 0.481884, actual reward 0.589264
# round 1747, predicted reward 0.391593, actual reward 0.458647
# round 1748, predicted reward 0.610166, actual reward 0.630585
# round 1749, predicted reward 0.014816, actual reward 0.017912
# round 1750, predicted reward 0.639298, actual reward 0.619072
# round 1751, predicted reward 0.032920, actual reward 0.089567
# round 1752, predicted reward 0.384516, actual reward 0.375838
# round 1753, predicted reward 0.612331, actual reward 0.654482
# round 1754, predicted reward 0.225825, actual reward 0.359104
# round 1755, predicted reward 0.637684, actual reward 0.578494
# round 1756, predicted reward 0.046028, actual reward 0.003083
# round 1757, predicted reward 0.508429, actual reward 0.594224
# round 1758, predicted reward 0.036382, actual reward 0.069970
# round 1759, predicted reward 0.158721, actual reward 0.223909
# round 1760, predicted reward 0.681344, actual reward 0.705331
# round 1761, predicted reward 0.523581, actual reward 0.609167
# round 1762, predicted reward 0.448389, actual reward 0.497670
# round 1763, predicted reward 0.286301, actual reward 0.393973
# round 1764, predicted reward 0.606783, actual reward 0.639729
# round 1765, predicted reward 0.636099, actual reward 0.622060
# round 1766, predicted reward 0.434915, actual reward 0.483274
# round 1767, predicted reward 0.356167, actual reward 0.340294
# round 1768, predicted reward 0.668763, actual reward 0.692878
# round 1769, predicted reward 0.040563, actual reward -0.163348
# round 1770, predicted reward 0.471904, actual reward 0.503388
# round 1771, predicted reward 0.484609, actual reward 0.572365
# round 1772, predicted reward 0.891490, actual reward 0.799096
# round 1773, predicted reward 0.008070, actual reward -0.109458
# round 1774, predicted reward 0.182690, actual reward 0.191899
# round 1775, predicted reward 0.160025, actual reward 0.278108
# round 1776, predicted reward 0.184971, actual reward 0.133012
# round 1777, predicted reward 0.027725, actual reward -0.296141
# round 1778, predicted reward 0.419836, actual reward 0.452827
# round 1779, predicted reward 0.211086, actual reward 0.235248
# round 1780, predicted reward 0.582652, actual reward 0.606387
# round 1781, predicted reward 0.563439, actual reward 0.611828
# round 1782, predicted reward 0.505292, actual reward 0.493661
# round 1783, predicted reward 0.435319, actual reward 0.499781
# round 1784, predicted reward 0.496446, actual reward 0.568730
# round 1785, predicted reward 0.645392, actual reward 0.673707
# round 1786, predicted reward 0.477438, actual reward 0.505005
# round 1787, predicted reward 0.379179, actual reward 0.465427
# round 1788, predicted reward 0.519075, actual reward 0.541692
# round 1789, predicted reward 0.370866, actual reward 0.338083
# round 1790, predicted reward 0.380397, actual reward 0.465522
# round 1791, predicted reward 0.760235, actual reward 0.725743
# round 1792, predicted reward 0.502707, actual reward 0.559167
# round 1793, predicted reward 0.323048, actual reward 0.314133
# round 1794, predicted reward 0.586209, actual reward 0.596739
# round 1795, predicted reward 0.493840, actual reward 0.523084
# round 1796, predicted reward 0.089829, actual reward 0.118998
# round 1797, predicted reward 0.505268, actual reward 0.508515
# round 1798, predicted reward 0.060920, actual reward 0.122245
# round 1799, predicted reward 0.587955, actual reward 0.659097
# round 1800, predicted reward 0.014791, actual reward -0.501091
# round 1801, predicted reward 0.426002, actual reward 0.378529
# round 1802, predicted reward 0.086427, actual reward 0.148213
# round 1803, predicted reward 0.175370, actual reward 0.172928
# round 1804, predicted reward 0.582542, actual reward 0.639010
# round 1805, predicted reward 0.305277, actual reward 0.342485
# round 1806, predicted reward 0.728183, actual reward 0.696722
# round 1807, predicted reward 0.256242, actual reward 0.311943
# round 1808, predicted reward 0.585527, actual reward 0.605358
# round 1809, predicted reward 0.706801, actual reward 0.705289
# round 1810, predicted reward 0.038709, actual reward 0.056542
# round 1811, predicted reward 0.555840, actual reward 0.614466
# round 1812, predicted reward 0.814814, actual reward 0.765113
# round 1813, predicted reward 0.253331, actual reward 0.270807
# round 1814, predicted reward 0.045608, actual reward 0.111431
# round 1815, predicted reward 0.006486, actual reward -0.188837
# round 1816, predicted reward 0.403251, actual reward 0.438677
# round 1817, predicted reward 0.764676, actual reward 0.707554
# round 1818, predicted reward 0.065685, actual reward -0.039988
# round 1819, predicted reward -0.043347, actual reward 0.000068
# round 1820, predicted reward 0.287448, actual reward 0.299837
# round 1821, predicted reward 0.476894, actual reward 0.536685
# round 1822, predicted reward 0.352108, actual reward 0.451667
# round 1823, predicted reward 0.187816, actual reward 0.180416
# round 1824, predicted reward 0.221648, actual reward 0.277452
# round 1825, predicted reward 0.026897, actual reward -0.142183
# round 1826, predicted reward 0.813257, actual reward 0.709947
# round 1827, predicted reward 0.871611, actual reward 0.780195
# round 1828, predicted reward 0.732877, actual reward 0.704554
# round 1829, predicted reward -0.019592, actual reward -0.202075
# round 1830, predicted reward 0.770939, actual reward 0.733895
# round 1831, predicted reward 0.025877, actual reward -0.005600
# round 1832, predicted reward 0.163390, actual reward 0.276590
# round 1833, predicted reward 0.374969, actual reward 0.361067
# round 1834, predicted reward 0.533608, actual reward 0.639107
# round 1835, predicted reward 0.458382, actual reward 0.507099
# round 1836, predicted reward 0.615786, actual reward 0.623624
# round 1837, predicted reward -0.037540, actual reward -0.121847
# round 1838, predicted reward 0.700215, actual reward 0.661688
# round 1839, predicted reward 0.114072, actual reward 0.143063
# round 1840, predicted reward -0.027234, actual reward 0.155956
# round 1841, predicted reward 0.111273, actual reward 0.223446
# round 1842, predicted reward 0.671522, actual reward 0.680379
# round 1843, predicted reward -0.002504, actual reward -0.325800
# round 1844, predicted reward 0.595443, actual reward 0.633339
# round 1845, predicted reward 0.758504, actual reward 0.691549
# round 1846, predicted reward -0.079855, actual reward -0.149583
# round 1847, predicted reward 0.069617, actual reward 0.044264
# round 1848, predicted reward 0.225700, actual reward 0.266557
# round 1849, predicted reward 0.713941, actual reward 0.698214
# round 1850, predicted reward -0.111313, actual reward -0.086321
# round 1851, predicted reward 0.218248, actual reward 0.293006
# round 1852, predicted reward 0.514253, actual reward 0.559929
# round 1853, predicted reward 0.425989, actual reward 0.475322
# round 1854, predicted reward 0.359119, actual reward 0.414278
# round 1855, predicted reward 0.441594, actual reward 0.548283
# round 1856, predicted reward 0.204038, actual reward 0.297722
# round 1857, predicted reward -0.003138, actual reward -0.099440
# round 1858, predicted reward 0.318806, actual reward 0.364391
# round 1859, predicted reward 0.485455, actual reward 0.501179
# round 1860, predicted reward 0.468344, actual reward 0.504976
# round 1861, predicted reward 0.486287, actual reward 0.574382
# round 1862, predicted reward 0.083403, actual reward 0.134068
# round 1863, predicted reward 0.769628, actual reward 0.704284
# round 1864, predicted reward 0.499672, actual reward 0.577561
# round 1865, predicted reward 0.472268, actual reward 0.491535
# round 1866, predicted reward 0.806844, actual reward 0.757024
# round 1867, predicted reward 0.282565, actual reward 0.269887
# round 1868, predicted reward 0.080550, actual reward 0.176079
# round 1869, predicted reward 0.114456, actual reward 0.080849
# round 1870, predicted reward 0.443158, actual reward 0.426090
# round 1871, predicted reward 0.698157, actual reward 0.701498
# round 1872, predicted reward 0.413398, actual reward 0.390944
# round 1873, predicted reward 0.519149, actual reward 0.521383
# round 1874, predicted reward 0.113646, actual reward -0.332187
# round 1875, predicted reward 0.360167, actual reward 0.464781
# round 1876, predicted reward 0.753628, actual reward 0.756411
# round 1877, predicted reward 0.388780, actual reward 0.478099
# round 1878, predicted reward 0.576131, actual reward 0.641842
# round 1879, predicted reward 0.424343, actual reward 0.445915
# round 1880, predicted reward 0.565372, actual reward 0.604642
# round 1881, predicted reward 0.696893, actual reward 0.724930
# round 1882, predicted reward 0.376080, actual reward 0.373146
# round 1883, predicted reward -0.051778, actual reward -0.222680
# round 1884, predicted reward 0.391807, actual reward 0.471846
# round 1885, predicted reward 0.491179, actual reward 0.483317
# round 1886, predicted reward 0.028857, actual reward 0.067701
# round 1887, predicted reward 0.002585, actual reward -0.120066
# round 1888, predicted reward -0.097211, actual reward -0.083455
# round 1889, predicted reward 0.352626, actual reward 0.393820
# round 1890, predicted reward 0.205236, actual reward 0.319929
# round 1891, predicted reward 0.719145, actual reward 0.702600
# round 1892, predicted reward 0.426831, actual reward 0.470099
# round 1893, predicted reward 0.534589, actual reward 0.521986
# round 1894, predicted reward 0.059474, actual reward 0.109352
# round 1895, predicted reward 0.310957, actual reward 0.446634
# round 1896, predicted reward -0.078152, actual reward -0.325809
# round 1897, predicted reward 0.357523, actual reward 0.395470
# round 1898, predicted reward 0.364405, actual reward 0.332806
# round 1899, predicted reward 0.357554, actual reward 0.462879
# round 1900, predicted reward 0.340441, actual reward 0.449238
# round 1901, predicted reward 0.092495, actual reward 0.037873
# round 1902, predicted reward 0.588573, actual reward 0.584369
# round 1903, predicted reward 0.360554, actual reward 0.386562
# round 1904, predicted reward 0.257526, actual reward 0.264730
# round 1905, predicted reward 0.560286, actual reward 0.587732
# round 1906, predicted reward 0.189328, actual reward 0.295764
# round 1907, predicted reward 0.563113, actual reward 0.611209
# round 1908, predicted reward 0.240282, actual reward 0.301158
# round 1909, predicted reward 0.678366, actual reward 0.693546
# round 1910, predicted reward 0.262411, actual reward 0.251671
# round 1911, predicted reward 0.291508, actual reward 0.261101
# round 1912, predicted reward -0.014875, actual reward -0.320346
# round 1913, predicted reward 0.058430, actual reward 0.307077
# round 1914, predicted reward 0.537366, actual reward 0.539753
# round 1915, predicted reward 0.676176, actual reward 0.664524
# round 1916, predicted reward 0.453382, actual reward 0.538034
# round 1917, predicted reward 0.772037, actual reward 0.738352
# round 1918, predicted reward 0.386280, actual reward 0.411105
# round 1919, predicted reward 0.463931, actual reward 0.493088
# round 1920, predicted reward 0.298007, actual reward 0.342957
# round 1921, predicted reward 0.396951, actual reward 0.424209
# round 1922, predicted reward 0.406893, actual reward 0.420622
# round 1923, predicted reward 0.815036, actual reward 0.737379
# round 1924, predicted reward 0.563019, actual reward 0.611708
# round 1925, predicted reward 0.105462, actual reward 0.171532
# round 1926, predicted reward 0.760261, actual reward 0.720531
# round 1927, predicted reward 0.632907, actual reward 0.600137
# round 1928, predicted reward 0.480098, actual reward 0.414877
# round 1929, predicted reward 0.895553, actual reward 0.795368
# round 1930, predicted reward 0.409371, actual reward 0.507119
# round 1931, predicted reward 0.585754, actual reward 0.568373
# round 1932, predicted reward 0.535780, actual reward 0.592863
# round 1933, predicted reward 0.405515, actual reward 0.466179
# round 1934, predicted reward 0.635742, actual reward 0.654874
# round 1935, predicted reward 0.191474, actual reward 0.333099
# round 1936, predicted reward 0.589146, actual reward 0.632826
# round 1937, predicted reward 0.866175, actual reward 0.796396
# round 1938, predicted reward 0.476325, actual reward 0.531375
# round 1939, predicted reward 0.664026, actual reward 0.648730
# round 1940, predicted reward 0.382883, actual reward 0.466986
# round 1941, predicted reward 0.246491, actual reward 0.348924
# round 1942, predicted reward 0.416975, actual reward 0.509131
# round 1943, predicted reward 0.299095, actual reward 0.409195
# round 1944, predicted reward 0.847907, actual reward 0.796906
# round 1945, predicted reward 0.962527, actual reward 0.810815
# round 1946, predicted reward 0.351008, actual reward 0.372913
# round 1947, predicted reward 0.614304, actual reward 0.627478
# round 1948, predicted reward 0.393924, actual reward 0.436633
# round 1949, predicted reward 0.721855, actual reward 0.703863
# round 1950, predicted reward 0.358889, actual reward 0.413895
# round 1951, predicted reward 0.173765, actual reward 0.115415
# round 1952, predicted reward 0.467540, actual reward 0.516991
# round 1953, predicted reward 0.552200, actual reward 0.542292
# round 1954, predicted reward 0.373589, actual reward 0.439710
# round 1955, predicted reward 0.589687, actual reward 0.686618
# round 1956, predicted reward 0.363093, actual reward 0.400162
# round 1957, predicted reward 0.545076, actual reward 0.541477
# round 1958, predicted reward 0.269119, actual reward 0.204374
# round 1959, predicted reward 0.242974, actual reward 0.267064
# round 1960, predicted reward 0.913615, actual reward 0.808061
# round 1961, predicted reward 0.644778, actual reward 0.700712
# round 1962, predicted reward 0.680318, actual reward 0.699497
# round 1963, predicted reward 0.528927, actual reward 0.556019
# round 1964, predicted reward 0.314349, actual reward 0.343369
# round 1965, predicted reward 0.199186, actual reward 0.308696
# round 1966, predicted reward 0.401115, actual reward 0.443804
# round 1967, predicted reward 0.454854, actual reward 0.575122
# round 1968, predicted reward 0.366823, actual reward 0.383601
# round 1969, predicted reward 0.206583, actual reward 0.202510
# round 1970, predicted reward 0.573588, actual reward 0.585180
# round 1971, predicted reward 0.768613, actual reward 0.723399
# round 1972, predicted reward 0.479190, actual reward 0.481335
# round 1973, predicted reward 0.809453, actual reward 0.734854
# round 1974, predicted reward 0.675762, actual reward 0.643904
# round 1975, predicted reward 0.578604, actual reward 0.531203
# round 1976, predicted reward 0.745616, actual reward 0.681263
# round 1977, predicted reward 0.238863, actual reward 0.268883
# round 1978, predicted reward 0.527747, actual reward 0.499839
# round 1979, predicted reward 0.334494, actual reward 0.346922
# round 1980, predicted reward 0.548822, actual reward 0.593961
# round 1981, predicted reward 0.684120, actual reward 0.674190
# round 1982, predicted reward 0.408198, actual reward 0.460392
# round 1983, predicted reward 0.581714, actual reward 0.619665
# round 1984, predicted reward 0.257021, actual reward 0.278830
# round 1985, predicted reward 0.671663, actual reward 0.661945
# round 1986, predicted reward 0.295157, actual reward 0.398029
# round 1987, predicted reward 0.163508, actual reward 0.219329
# round 1988, predicted reward 0.543652, actual reward 0.548961
# round 1989, predicted reward 0.242936, actual reward 0.191668
# round 1990, predicted reward 0.705920, actual reward 0.720654
# round 1991, predicted reward 0.278806, actual reward 0.318703
# round 1992, predicted reward 0.481767, actual reward 0.609876
# round 1993, predicted reward 0.451770, actual reward 0.449417
# round 1994, predicted reward 0.661541, actual reward 0.669433
# round 1995, predicted reward 0.187802, actual reward 0.197987
# round 1996, predicted reward 0.237256, actual reward 0.159511
# round 1997, predicted reward 0.139843, actual reward 0.081412
# round 1998, predicted reward 0.189429, actual reward 0.226081
# round 1999, predicted reward 0.389223, actual reward 0.462809

# %%
# Best agent benchmark
np.random.seed(12345)

# reward = np.zeros(T)
# X_history = np.zeros((d, T))
# params_history = {}
# grad_history = {}

bestagent = BestAgent(K, T, d)
for tt in range(1, T + 1):
    # observe \{x_{t,a}\}_{a=1}^{k=1}
    context_list = SampleContext(d, K)
    
    # compute the upper bound of reward
    ind = bestagent.Action(context_list)
    
    # play ind and observe reward
    reward = GetRealReward(context_list[:, ind], A)
    bestagent.Update(reward)

# %%
# Uniform agent benchmark
np.random.seed(12345)

uniformagent = UniformAgent(K, T, d)
for tt in range(1, T + 1):
    # observe \{x_{t,a}\}_{a=1}^{k=1}
    context_list = SampleContext(d, K)
    
    # compute the upper bound of reward
    ind = uniformagent.Action(context_list)
    
    # play ind and observe reward
    reward = GetRealReward(context_list[:, ind], A)
    uniformagent.Update(reward)

# %%
import matplotlib.pyplot as plt
h_r_b = bestagent.history_reward
plt.plot(range(0, T), np.cumsum(h_r_b))

h_r_u = uniformagent.history_reward
plt.plot(range(0, T), np.cumsum(h_r_u))

h_r_n = neuralagent.history_reward
plt.plot(range(0, T), np.cumsum(h_r_n))

plt.legend(["Best", "Uniform", "Neural"])
# plt.legend(["Best", "Uniform"])
plt.xlabel("Round Index")
plt.ylabel("Total Reward")
# Out:
# Text(0, 0.5, 'Total Reward')

# %%
plt.plot(range(100, T), np.cumsum(h_r_n)[100:T] / np.cumsum(h_r_b)[100:T])
plt.plot(range(100, T), np.cumsum(h_r_u)[100:T] / np.cumsum(h_r_n)[100:T])
plt.legend(["Neural / Best", "Uniform / Neural"])
plt.plot(range(100, T), np.ones(T)[100:T])
plt.plot(range(100, T), 0.9 * np.ones(T)[100:T])

# %%
# GetRealReward(np.array([0, 1]), np.array([1, 0]))
